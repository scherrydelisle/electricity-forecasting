# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from gsodpy import fetch_years
#
# ImportError: cannot import name 'fetch_years' from 'gsodpy' (/home/stche/.virtualenvs/electricity-forecasting/lib/python3.12/site-packages/gsodpy/__init__.py)
